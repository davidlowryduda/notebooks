# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
def make_one_plot(fn=1, xmin=-1, xmax=1, ymin=-1, ymax=1, xtick_mult=1, ytick_mult=1, figname="plot", clist=None):
    global counter
    savename = figname + str(counter) + ".pdf"
    counter = counter + 1
    FIGSIZEX = 3
    FIGSIZEY = 3

    xs = np.linspace(xmin, xmax)
    if not clist:
        clist = [-1 + x*1./3 for x in range(7)] 
    for c in clist:
        f = lambda x: fn(x, c)
        ys = np.array(list(map(f, xs)))
        plt.plot(xs, ys, color='k')
    
    axes = plt.gca()
    axes.spines['top'].set_visible(False)
    axes.spines['right'].set_visible(False)
    #axes.spines['left'].set_position('zero')
    #axes.spines['bottom'].set_position('zero')
    #xticks = [-10 + .5*x for x in range(41)]
    xticks = [xtick_mult*(-10 + x) for x in range(21)]
    yticks = [ytick_mult*(-20 + x) for x in range(41)]
    plt.xticks(xticks)
    plt.yticks(yticks)
    plt.xlim([xmin, xmax])
    plt.ylim([ymin, ymax])
    plt.xlabel("x")
    plt.ylabel("y")
    axes.grid(True, linestyle='--')
    
    fig = plt.gcf()
    fig.set_size_inches(FIGSIZEX, FIGSIZEY)
    fig.savefig(savename, bbox_inches='tight')

# %%
counter = 1

# %%
counter = 1
def fn(x,c):
    return math.cos(x) - math.sin(x)
make_one_plot(fn, xmin=-3.14, xmax=3.14, ymin=-2, ymax=2, figname="ex44_2_1", clist=[0])

# %%
counter = 1
def fn(x,c):
    return math.sqrt(2) * (math.cos(x + 3.14159/4))
make_one_plot(fn, xmin=-3.14, xmax=3.14, ymin=-2, ymax=2, figname="ex44_2_2", clist=[0])

# %%
counter = 1
def fn(x,c):
    return (-1./15) * math.sin(6*x)
make_one_plot(fn, xmin=-3.14, xmax=3.14, ymin=-.2, ymax=.2, figname="ex44_2_12", clist=[0])

# %%
counter = 1
def fn(x,c):
    return -3 * math.exp(-x) + 2 * math.exp(-2*x)
make_one_plot(fn, xmin=0, xmax=10, ymin=-1.5, ymax=1.5, xtick_mult=2, figname="ex44_2_16", clist=[0])

# %%
counter = 1
def fn(x,c):
    return -(0.15 + 1.05 * x) * math.exp(-7 * x)
make_one_plot(fn, xmin=0, xmax=10, ymin=-.2, ymax=.2, xtick_mult=2, ytick_mult=0.1, figname="ex44_2_18", clist=[0])

# %%
counter = 1
def fn(x,c):
    return 0.1532 * math.exp(-7.5 * x) * math.cos(math.sqrt(167)*x/2 - 0.8597)
make_one_plot(fn, xmin=0, xmax=2, ymin=-.1, ymax=.1, xtick_mult=.5, ytick_mult=0.05, figname="ex44_2_22", clist=[0])
